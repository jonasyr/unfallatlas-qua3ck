# %% [markdown]
# # Größen & Qualität
# Repräsentative Offline-Galerie für die Browserprüfung.

# %% [markdown]
# ## Größen & Qualität
# Doppelte Überschrift mit Umlauten und Sonderzeichen.

# %% [markdown]
# ### Tabellen & Protokolle
# #### Grafiken
# Alle Inhalte stammen aus gespeicherten MIME-Ausgaben.

# %%
stored_value = 42
stored_value
# Out:
# Gespeicherter Textoutput: 42

# %%
configuration = {"offline": True}
saved_table = {"rows": 200, "columns": 10}
saved_log = "320 stored validation steps"
saved_svg = "<svg>stored chart</svg>"
saved_png = b"stored PNG bytes"
saved_figure = {"kind": "plotly", "stored": True}

# %%
display(saved_table)
# Out:
# <200 rows × 10 columns>

# %%
print(saved_log)
# Out:
# Protokollzeile 001: gespeicherter Validierungsschritt abgeschlossen.
# Protokollzeile 002: gespeicherter Validierungsschritt abgeschlossen.
# Protokollzeile 003: gespeicherter Validierungsschritt abgeschlossen.
# Protokollzeile 004: gespeicherter Validierungsschritt abgeschlossen.
# Protokollzeile 005: gespeicherter Validierungsschritt abgeschlossen.
# Protokollzeile 006: gespeicherter Validierungsschritt abgeschlossen.
# Protokollzeile 007: gespeicherter Validierungsschritt abgeschlossen.
# Protokollzeile 008: gespeicherter Validierungsschritt abgeschlossen.
# Protokollzeile 009: gespeicherter Validierungsschritt abgeschlossen.
# Protokollzeile 010: gespeicherter Validierungsschritt abgeschlossen.
# Protokollzeile 011: gespeicherter Validierungsschritt abgeschlossen.
# Protokollzeile 012: gespeicherter Validierungsschritt abgeschlossen.
# Protokollzeile 013: gespeicherter Validierungsschritt abgeschlossen.
# Protokollzeile 014: gespeicherter Validierungsschritt abgeschlossen.
# ...

# %%
display(saved_svg)
# Out:
# <SVG example>

# %%
display(saved_png)
# Out:
# <PNG example>

# %%
display(saved_figure)
# Out:
# Figure({saved Plotly MIME bundle})
